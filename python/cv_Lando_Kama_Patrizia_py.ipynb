# %%
# === CONTACT ===
def afficher_contact(email, telephone, localisation, linkedin, github, kaggle, medium):
    print("📧 Email:", email)
    print("📞 Téléphone:", telephone)
    print("📍 Localisation:", localisation)
    print("🔗 LinkedIn:", linkedin)
    print("💻 GitHub:", github)
    print("📊 Kaggle:", kaggle)
    print("✍️ Medium Blog:", medium)

# === OBJECTIF ===
objectif = """\
Je suis une jeune femme déterminée, créative et passionnée par l’analyse de données. Bien que mon parcours ne soit pas linéaire, j’ai toujours su me remettre en question, apprendre et évoluer sans peur du changement.

Future Data Analyst en formation Bac+5 chez OpenClassrooms, avec un double Master en économie et modélisation des données.

Je cherche un stage ou une alternance à partir de septembre 2025 en tant que Data Analyst, dans une entreprise inclusive, ouverte à la diversité et prête à valoriser de nouveaux talents.

Je peux offrir :
▪️ Une solide maîtrise d’outils comme Python, SQL, Excel avancé et Power BI, appliqués à des projets concrets de nettoyage, visualisation et modélisation des données ;
▪️ Une capacité à apprendre rapidement, à m’adapter à différents environnements et à gérer un projet de bout en bout ;
▪️ Une approche curieuse, rigoureuse et autonome, avec un fort intérêt pour des sujets à impact (énergie, durabilité, inclusion).

📍 Basée en France, je suis disponible pour une mobilité internationale (Belgique, Suisse, Luxembourg…), avec des liens personnels dans plusieurs pays européens.
"""


# === LANGAGES DE PROGRAMMATION & OUTILS ===
langages = ["Python (Pandas, Numpy, Matplotlib)", "SQL (MySQL, PostgreSQL, SQL Server)", "R"]
outils = ["Jupyter", "Google Colab", "Microsoft Dynamics 365", "Microsoft Office (Word, PowerPoint, Excel)"]

# === PROJETS ACTUELS ===
projets = [
    {
        "Poste": "Data Analyst",
        "Entreprise": "MyDataBreakfast",
        "Durée": "Depuis juin 2025",
        "Description": "Création de contenus pédagogiques (Python, pandas, matplotlib, SQL, R) pour vulgarisation technique"
    },
    {
        "Poste": "Data Analyst",
        "Entreprise": "INCO Academy, Paris",
        "Durée": "Depuis mai 2025",
        "Description": "Nettoyage, modélisation et visualisation avec Excel et Python, analyse prédictive sur dataset open-source"
    }
]

# === EXPÉRIENCES PROFESSIONNELLES ===
experiences = [
    {
        "Poste": "📈 Stagiaire Data Analyst Finance",
        "Entreprise": "Marsovin Winery, Malte",
        "Durée": "Janv. 2023 à août 2023",
        "Description": "Automatisation reporting (-70% temps), KPI ventes, nettoyage données (-15%)"
    },
    {
        "Poste": "📊 Junior Data Analyst (Budget & Reporting)",
        "Entreprise": "SitUnited Finance, Italie",
        "Durée": "Mars 2021 à déc. 2021",
        "Description": "Reporting financier, analyse marketing (+25%), modèle prédictif (+15%), réduction coûts (-10%)"
    },
    {
        "Poste": "🎓 Tuteur Digital",
        "Entreprise": "Fondation Ufficio Pio, Italie",
        "Durée": "Avril 2022 à déc. 2022",
        "Description": "Animation ateliers Pack Office pour +20 participants, taux de satisfaction: 95%"
    }
]

# === ENGAGEMENTS ===
engagements = [
    {"Poste": "Data Entry", "Entreprise": "🌍 Mouvement des Consommateurs"},
    {"Poste": "Délégation", "Entreprise": "Comité Femmes Étrangères"},
    {"Poste": "Délégation", "Entreprise": "OJUEA (UE–Afrique)"},
    {"Poste": "Délégation", "Entreprise": "OTAN & ONU"}
]

# === FORMATIONS CONTINUES ===
formations_continues = [
    {"Titre": "Data Science", "Organisme": "Develhope", "Année": "Depuis juin 2025"},
    {"Titre": "Data Analyst | Data Science | Business Analysis", "Organisme": "Yimp", "Année": "Depuis mai 2025"},
    {"Titre": "Kit Data Science", "Organisme": "DataMaster", "Année": "Depuis avril 2025"}
]

# === CERTIFICATIONS ===
certifications = [
    {"Titre": "Google Data Analyst", "Organisme": "Coursera", "Année": 2024},
    {"Titre": "Data Analyst", "Organisme": "Tree School", "Année": 2024},
    {"Titre": "Python pour la Finance", "Organisme": "Redige", "Année": 2024}
]

# === FORMATION ACADÉMIQUE ===
formation_academique = [
    {
        "Diplôme": "Diplôme Data Analyst (Bac+3/4) – Alternance",
        "Établissement": "OpenClassrooms",
        "Année": "Depuis sept. 2025"
    },
    {
        "Diplôme": "Master I | Analyse & Modélisation des Données",
        "Établissement": "Unitelma Sapienza, Rome",
        "Année": "Depuis déc. 2023"
    },
    {
        "Diplôme": "Master II en Économie & Gestion | Économie Internationale",
        "Établissement": "Université de Turin",
        "Année": "Oct. 2018 à Nov. 2022"
    },
    {
        "Diplôme": "Licence en Sciences du Développement & Coopération",
        "Établissement": "Université de Turin",
        "Année": "Oct. 2016 à Nov. 2018"
    }
]

# === AFFICHAGE ===

print("\n=== 👩‍💻 PATRIZIA LANDO KAMA ===")
afficher_contact(
    email="xxxxxxxxxxxxxxxxxxxxx",
    telephone="xxxxxxxxxxxxxxxxxxx",
    localisation="Paris, France",
    linkedin="https://www.linkedin.com/in/patrizia-lando-kama99/",
    github="https://github.com/PatriziaLandokama9",
    kaggle="https://www.kaggle.com/patrizialandokama",
    medium="https://medium.com/@patrizia.lando.kama9"
)

print("\n=== 🎯 OBJECTIF PROFESSIONNEL ===")
print(objectif)

print("\n=== 💻 LANGAGES DE PROGRAMMATION ===")
print(", ".join(langages))

print("\n=== 🧰 OUTILS ===")
print(", ".join(outils))

print("\n=== 📂 PROJETS / ACTIVITÉS EN COURS ===")
for projet in projets:
    print(f"- {projet['Poste']} chez {projet['Entreprise']} ({projet['Durée']}): {projet['Description']}")

print("\n=== 💼 EXPÉRIENCE PROFESSIONNELLE ===")
for exp in experiences:
    print(f"- {exp['Poste']} chez {exp['Entreprise']} ({exp['Durée']}): {exp['Description']}")

print("\n=== 🌱 ENGAGEMENTS ===")
for eng in engagements:
    print(f"- {eng['Poste']} chez {eng['Entreprise']}")

print("\n=== 🎓 FORMATIONS CONTINUES ===")
for fc in formations_continues:
    print(f"- {fc['Titre']} ({fc['Organisme']}, {fc['Année']})")

print("\n=== 📜 CERTIFICATIONS ===")
for cert in certifications:
    print(f"- {cert['Titre']} ({cert['Organisme']}, {cert['Année']})")

print("\n=== 🎓 FORMATION ACADÉMIQUE ===")
for fac in formation_academique:
    print(f"- {fac['Diplôme']} ({fac['Établissement']}, {fac['Année']})")
# Out:
# === 👩‍💻 PATRIZIA LANDO KAMA ===
# 📧 Email: xxxxxxxxxxxxxxxxxxxxx
# 📞 Téléphone: xxxxxxxxxxxxxxxxxxx
# 📍 Localisation: Paris, France
# 🔗 LinkedIn: https://www.linkedin.com/in/patrizia-lando-kama99/
# 💻 GitHub: https://github.com/PatriziaLandokama9
# 📊 Kaggle: https://www.kaggle.com/patrizialandokama
# ✍️ Medium Blog: https://medium.com/@patrizia.lando.kama9
#
# === 🎯 OBJECTIF PROFESSIONNEL ===
# Je suis une jeune femme déterminée, créative et passionnée par l’analyse de données. Bien que mon parcours ne soit pas linéaire, j’ai toujours su me remettre en question, apprendre et évoluer sans peur du changement.
#
# Future Data Analyst en formation Bac+5 chez OpenClassrooms, avec un double Master en économie et modélisation des données.
#
# Je cherche un stage ou une alternance à partir de septembre 2025 en tant que Data Analyst, dans une entreprise inclusive, ouverte à la diversité et prête à valoriser de nouveaux talents.
#
# Je peux offrir :
# ...
